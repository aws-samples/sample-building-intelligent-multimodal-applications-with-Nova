# %% [markdown]
# # 🎙️ Building Smart Voice Chat with Amazon Nova2
#
# ## 🎯 What You'll Learn
# - How to capture audio from microphone using Python
# - How to use Amazon Nova2 Omni for audio transcription
# - How to build conversational AI with language detection
# - How to create interactive Jupyter widgets
#
# Let's build this step by step! 🚀

# %%
# !pip install ipywidgets sounddevice numpy
# !pip install -r ../requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Requirement already satisfied: ipywidgets in /opt/anaconda3/lib/python3.13/site-packages (8.1.5)
# Collecting sounddevice
#   Using cached sounddevice-0.5.3-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.1.3)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: CFFI>=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from CFFI>=1.0->sounddevice) (2.21)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Using cached sounddevice-0.5.3-py3-none-macosx_10_6_x86_64.macosx_10_6_universal2.whl (108 kB)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.5.3
# Looking in indexes: https://pypi.org/simple, https://plugin.us-east-1.prod.workshops.aws
# Requirement already satisfied: botocore>=1.42.1 in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: boto3>=1.42.1 in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (1.42.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 3)) (2.32.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 4)) (6.29.5)
# Requirement already satisfied: awscli in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 6)) (1.43.7)
# Requirement already satisfied: sagemaker in /opt/anaconda3/lib/python3.13/site-packages (from -r ../requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from botocore>=1.42.1->-r ../requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/lib/python3.13/site-packages (from botocore>=1.42.1->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/anaconda3/lib/python3.13/site-packages (from botocore>=1.42.1->-r ../requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.42.1->-r ../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from boto3>=1.42.1->-r ../requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->-r ../requirements.txt (line 3)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->-r ../requirements.txt (line 3)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->-r ../requirements.txt (line 3)) (2025.8.3)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (8.30.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from ipykernel->-r ../requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: docutils<=0.19,>=0.18.1 in /opt/anaconda3/lib/python3.13/site-packages (from awscli->-r ../requirements.txt (line 6)) (0.19)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /opt/anaconda3/lib/python3.13/site-packages (from awscli->-r ../requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in /opt/anaconda3/lib/python3.13/site-packages (from awscli->-r ../requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from awscli->-r ../requirements.txt (line 6)) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from rsa<4.8,>=3.1.2->awscli->-r ../requirements.txt (line 6)) (0.4.8)
# Requirement already satisfied: sagemaker-core<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker->-r ../requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: sagemaker-train<2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker->-r ../requirements.txt (line 7)) (1.0)
# Requirement already satisfied: sagemaker-serve<2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker->-r ../requirements.txt (line 7)) (1.0)
# Requirement already satisfied: sagemaker-mlops<2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker->-r ../requirements.txt (line 7)) (1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.12.3)
# Requirement already satisfied: jsonschema<5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.25.0)
# Requirement already satisfied: platformdirs<5.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.3.7)
# Requirement already satisfied: rich<14.0.0,>=13.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (13.9.4)
# Requirement already satisfied: mock<5.0,>4.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.0.3)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (6.11.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.14.1)
# Requirement already satisfied: pytz>=2021.1 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2024.1)
# Requirement already satisfied: attrs>=20.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.25.8)
# Requirement already satisfied: pandas>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.2.3)
# Requirement already satisfied: numpy>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: smdebug_rulesconfig>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: schema>=0.7.5 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.7.8)
# Requirement already satisfied: omegaconf>=2.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.3.0)
# Requirement already satisfied: torch>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.9.1)
# Requirement already satisfied: scipy>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.15.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.21.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema<5.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.26.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: deepdiff in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (8.6.1)
# Requirement already satisfied: mlflow in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: sagemaker_schema_inference_artifacts in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.0.5)
# Requirement already satisfied: pytest in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (8.4.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: tritonclient[http] in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.63.0)
# Requirement already satisfied: onnx in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.20.0)
# Requirement already satisfied: onnxruntime in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.23.2)
# Requirement already satisfied: graphene<4,>=3 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: tblib>=1.7.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: paramiko>=2.11.0 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from graphene<4,>=3->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (3.0.51)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.13/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/anaconda3/lib/python3.13/site-packages (from omegaconf>=2.1.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.9.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=1.0.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2025.2)
# Requirement already satisfied: bcrypt>=3.2 in /opt/anaconda3/lib/python3.13/site-packages (from paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.3.0)
# Requirement already satisfied: cryptography>=3.3 in /opt/anaconda3/lib/python3.13/site-packages (from paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (44.0.1)
# Requirement already satisfied: invoke>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: pynacl>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.13/site-packages (from cryptography>=3.3->paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.13/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.11.0->sagemaker-train<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.21)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.17.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.8.8)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.13/site-packages (from torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2025.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: orderly-set<6,>=5.4.1 in /opt/anaconda3/lib/python3.13/site-packages (from deepdiff->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=1.9.0->sagemaker-core<3.0.0,>=2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: Flask<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.16.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: gunicorn<24 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.5.4)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (19.0.0)
# Requirement already satisfied: scikit-learn<2 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.6.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.0.39)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.73.0)
# Requirement already satisfied: fastapi<1 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.120.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.1.43)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.37.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda3/lib/python3.13/site-packages (from mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.38.0)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.2.3)
# Requirement already satisfied: google-auth~=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.43.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.47.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.13/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.0.3)
# Requirement already satisfied: Werkzeug>=3.1 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /opt/anaconda3/lib/python3.13/site-packages (from Flask<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.2.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib<4->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /opt/anaconda3/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.58b0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn<2->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda3/lib/python3.13/site-packages (from starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.16.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from onnx->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.5.4)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.13/site-packages (from onnxruntime->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (25.9.23)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/lib/python3.13/site-packages (from coloredlogs->onnxruntime->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (10.0)
# Requirement already satisfied: iniconfig>=1 in /opt/anaconda3/lib/python3.13/site-packages (from pytest->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: pluggy<2,>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from pytest->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: json5>=0.9.22 in /opt/anaconda3/lib/python3.13/site-packages (from sagemaker_schema_inference_artifacts->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.9.25)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.13/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 4)) (0.2.2)
# Requirement already satisfied: perf-analyzer in /opt/anaconda3/lib/python3.13/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: python-rapidjson>=0.9.1 in /opt/anaconda3/lib/python3.13/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.22)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.13/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.11.10)
# Requirement already satisfied: geventhttpclient>=2.3.3 in /opt/anaconda3/lib/python3.13/site-packages (from tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.1->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.18.0)
# Requirement already satisfied: gevent in /opt/anaconda3/lib/python3.13/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (25.9.1)
# Requirement already satisfied: brotli in /opt/anaconda3/lib/python3.13/site-packages (from geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: greenlet>=3.2.2 in /opt/anaconda3/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (3.2.4)
# Requirement already satisfied: zope.event in /opt/anaconda3/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (6.1)
# Requirement already satisfied: zope.interface in /opt/anaconda3/lib/python3.13/site-packages (from gevent->geventhttpclient>=2.3.3->tritonclient[http]->sagemaker-serve<2.0.0->sagemaker->-r ../requirements.txt (line 7)) (7.1.1)

# %%
import boto3
import json
import base64
import sounddevice as sd
import numpy as np
import wave
from datetime import datetime
import ipywidgets as widgets
from IPython.display import display, clear_output
import io

bedrock_runtime = boto3.client('bedrock-runtime', region_name='us-west-2')

# %%
class VoiceRecorder:
    def __init__(self):
        self.sample_rate = 16000
        self.recording = False
        self.audio_data = []
        
    def start(self):
        self.recording = True
        self.audio_data = []
        
        def callback(indata, frames, time, status):
            if self.recording:
                self.audio_data.append(indata.copy())
        
        self.stream = sd.InputStream(callback=callback, samplerate=self.sample_rate, channels=1, dtype=np.float32)
        self.stream.start()
        
    def stop(self):
        self.recording = False
        if hasattr(self, 'stream'):
            self.stream.stop()
            self.stream.close()
        
        if self.audio_data:
            audio_array = np.concatenate(self.audio_data, axis=0)
            audio_int16 = (audio_array * 32767).astype(np.int16)
            
            wav_buffer = io.BytesIO()
            with wave.open(wav_buffer, 'wb') as wav_file:
                wav_file.setnchannels(1)
                wav_file.setsampwidth(2)
                wav_file.setframerate(self.sample_rate)
                wav_file.writeframes(audio_int16.tobytes())
            wav_buffer.seek(0)
            return wav_buffer.getvalue()
        return None

# %%
def chat_with_ai(audio_bytes):
    """Single-call AI processing: Audio → Transcription + Analysis & Response"""
    try:
        audio_base64 = base64.b64encode(audio_bytes).decode('utf-8')
        
        # Single call: Transcribe audio and generate intelligent response
        response = bedrock_runtime.invoke_model(
            modelId="us.amazon.nova-2-omni-v1:0",
            contentType="application/json",
            accept="application/json",
            body=json.dumps({
                "messages": [{
                    "role": "user",
                    "content": [
                        {"audio": {"format": "wav", "source": {"bytes": audio_base64}}},
                        {"text": """Given this input text:
    1. Transcribe the text exactly
    2. Detect language and analyze emotional tone
    3. Provide a natural response matching the language and tone

    Required output format:
    TRANSCRIPTION: [exact text]

    ANALYSIS:
    - Language: [detected language]
    - Tone: [primary emotion, intensity, key characteristics]

    RESPONSE: [natural conversational reply in matching language and tone]"""}
                    ]
                }],
                "inferenceConfig": {"maxTokens": 1000, "temperature": 0.7}
            })
        )
        
        result = json.loads(response['body'].read())
        full_response = result['output']['message']['content'][0]['text']
        
        # Parse transcription and AI response
        if 'TRANSCRIPTION:' in full_response:
            parts = full_response.split('\n\n', 1)
            user_text = parts[0].replace('TRANSCRIPTION:', '').strip()
            ai_response = parts[1] if len(parts) > 1 else "[Language: Unknown | Tone: Neutral] I heard you but couldn't analyze properly."
        else:
            user_text = "Audio processed"
            ai_response = full_response
        
        return user_text, ai_response
        
    except Exception as e:
        return "Error", f"[Language: Unknown | Tone: Error] Sorry, I encountered an error: {e}"

# %%
class EnhancedVoiceChat:
    def __init__(self):
        self.recorder = VoiceRecorder()
        self.conversation = []
        self.setup_ui()
        
    def setup_ui(self):
        self.talk_btn = widgets.Button(
            description='🎙️ Start Recording',
            button_style='success',
            layout=widgets.Layout(width='200px', height='60px')
        )
        self.stop_btn = widgets.Button(
            description='⏹️ Send Message',
            button_style='primary',
            disabled=True,
            layout=widgets.Layout(width='200px', height='60px')
        )
        self.clear_btn = widgets.Button(
            description='🗑️ New Chat',
            button_style='warning',
            layout=widgets.Layout(width='150px')
        )
        
        self.status = widgets.HTML("<div style='padding: 15px; text-align: center; background: #f0f0f0; border-radius: 10px;'>🎯 Ready to analyze your voice!</div>")
        self.chat_display = widgets.Output(layout=widgets.Layout(height='2400px', overflow='auto'))
        self.message_count = widgets.HTML("<b>💬 Messages: 0</b>")
        
        self.talk_btn.on_click(self.start_talking)
        self.stop_btn.on_click(self.stop_talking)
        self.clear_btn.on_click(self.clear_chat)
    
    def start_talking(self, btn):
        self.recorder.start()
        self.talk_btn.disabled = True
        self.stop_btn.disabled = False
        self.status.value = "<div style='background: #ff4444; color: white; padding: 15px; border-radius: 10px; text-align: center;'><h3>🔴 RECORDING...</h3><p>Speak naturally - I'll analyze your language and tone!</p></div>"
    
    def stop_talking(self, btn):
        self.status.value = "<div style='background: #4CAF50; color: white; padding: 15px; border-radius: 10px; text-align: center;'><h3>🤖 Analyzing speech...</h3><p>Detecting language and tone</p></div>"
        
        audio_bytes = self.recorder.stop()
        
        if audio_bytes:
            user_text, ai_response = chat_with_ai(audio_bytes)
            
            timestamp = datetime.now().strftime('%H:%M')
            self.conversation.append({'type': 'user', 'text': user_text, 'time': timestamp})
            self.conversation.append({'type': 'ai', 'text': ai_response, 'time': timestamp})
            
            self.update_chat_display()
            self.message_count.value = f"<b>💬 Messages: {len(self.conversation)}</b>"
            self.status.value = "<div style='background: #2196F3; color: white; padding: 15px; border-radius: 10px; text-align: center;'><h3>✅ Analysis complete!</h3><p>Ready for next message</p></div>"
        
        self.talk_btn.disabled = False
        self.stop_btn.disabled = True
    
    def update_chat_display(self):
        with self.chat_display:
            clear_output(wait=True)
            
            if not self.conversation:
                print("🎙️ Start speaking to see language and tone analysis!")
                return
            
            for msg in self.conversation:
                if msg['type'] == 'user':
                    print(f"\n👤 YOU ({msg['time']})")
                    print(f"┌─ {msg['text']}")
                    print("└" + "─" * 60)
                else:
                    print(f"\n🤖 AI ASSISTANT ({msg['time']})")
                    if '[Language:' in msg['text']:
                        parts = msg['text'].split('] ', 1)
                        if len(parts) == 2:
                            analysis = parts[0] + ']'
                            response = parts[1]
                            print(f"🔍 {analysis}")
                            print(f"┌─ {response}")
                        else:
                            print(f"┌─ {msg['text']}")
                    else:
                        print(f"┌─ {msg['text']}")
                    print("└" + "─" * 60)
    
    def clear_chat(self, btn):
        self.conversation = []
        self.message_count.value = "<b>💬 Messages: 0</b>"
        self.update_chat_display()
        self.status.value = "<div style='background: #FF9800; color: white; padding: 15px; border-radius: 10px; text-align: center;'><h3>🆕 New chat started!</h3><p>Ready to analyze your voice</p></div>"
    
    def display(self):
        header = widgets.HTML(
            "<div style='background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 25px; border-radius: 15px; text-align: center; margin-bottom: 20px;'>"
            "<h1>🗣️ Smart Voice Chat Workshop</h1>"
            "<p>AI analyzes your language, tone & responds naturally • Multi-language support</p>"
            "</div>"
        )
        
        controls = widgets.VBox([
            widgets.HBox([self.talk_btn, self.stop_btn], layout=widgets.Layout(justify_content='center', margin='0 0 15px 0')),
            widgets.HBox([self.message_count, self.clear_btn], layout=widgets.Layout(justify_content='space-between')),
            self.status
        ])
        
        chat_area = widgets.VBox([
            widgets.HTML("<h3 style='color: #333;'>💬 Conversation with Analysis</h3>"),
            self.chat_display
        ], layout=widgets.Layout(border='2px solid #ddd', padding='15px', border_radius='10px', margin='15px 0'))
        
        tips = widgets.HTML(
            "<div style='background: #e8f5e8; padding: 15px; border-radius: 10px; border-left: 4px solid #4caf50;'>"
            "<h4>🎯 Workshop Features:</h4>"
            "<ul>"
            "<li><b>Language Detection:</b> AI identifies what language you're speaking</li>"
            "<li><b>Tone Analysis:</b> Detects emotional tone (happy, sad, excited, etc.)</li>"
            "<li><b>Natural Response:</b> Responds in your language with appropriate tone</li>"
            "<li><b>Single-Call Processing:</b> Audio → Transcription + Analysis & Response</li>"
            "</ul>"
            "</div>"
        )
        
        layout = widgets.VBox([header, controls, chat_area, tips])
        display(layout)
        
        self.update_chat_display()

# %% [markdown]
# ## 🚀 Launch the Workshop Application
#
# **Ready to test your voice chat!**
#
# Try speaking in different languages to see how the AI detects and responds!

# %%
chat = EnhancedVoiceChat()
chat.display()
